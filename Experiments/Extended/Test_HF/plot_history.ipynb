# %% [markdown]
# # Test Recurrent Policy with Extreme Parameter Variation

# %%
import numpy as np
import os,sys



sys.path.append('../../../../RL_lib/Agents')
sys.path.append('../../../../RL_lib/Policies/PPO')
sys.path.append('../../../../RL_lib/Policies/Common')
sys.path.append('../../../../RL_lib/Utils')
sys.path.append('../../../Env')
sys.path.append('../../../Imaging')


# %load_ext autoreload
# %load_ext autoreload
# %autoreload 2
# %matplotlib nbagg
import os
print(os.getcwd())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/briangaudet/Study/Subjects/MachineLearning/Projects/RL4GNC/Asteroid_CPO_seeker/Experiments/Extended/Test_HF

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %% [markdown]
# # Optimize Policy

# %%
from lander_model import Lander_model
from ic_gen import Landing_icgen
import rl_utils
logger = rl_utils.Logger()

# %%
from render_traj_seeker import render_traj
traj = np.load('traj_1.npy').item()
render_traj(traj)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import plot_rl_stats2
fname = "optimize_WATTVW_FOV-AR=5_history"
rl_stats = plot_rl_stats2.RL_stats(None,logger)
rl_stats.load_history(fname)
rl_stats.plot_rewards()
rl_stats.plot_rf()
rl_stats.plot_vf()
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="960">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="960">
# <img src="data:image/png;base64,..." width="960">

# %%
print(rl_stats.history.keys())
# Out:
# dict_keys(['MaxSteps', 'Norm_vf', 'SD_af', 'ExplainedVarNew', 'Max_vf', 'Max_wf', 'Variance', 'Beta', 'PolicyEntropy', 'Max_rf', 'Episode', 'Norm_rf', 'StdReward', 'KL', 'Norm_wf', 'MeanSteps', 'Norm_af', 'SD_rf', 'MeanReward', 'SD_vf', 'Model P Loss Old', 'SD_wf', 'MinReward', 'Max_af', 'Model ExpVarOld'])

# %%
print(env.rl_stats.history.keys())
# Out:
# dict_keys(['MaxSteps', 'Policy_Beta', 'SD_rf', 'SD_af', 'Max_vf', 'ExplainedVarNew', 'Max_wf', 'Variance', 'Max_rf', 'Episode', 'Norm_rf', 'StdReward', 'Norm_wf', 'MeanSteps', 'Norm_af', 'Model P Loss Old', 'Norm_vf', 'MeanReward', 'SD_vf', 'Policy_Entropy', 'Policy_KL', 'SD_wf', 'MinReward', 'Max_af', 'Model ExpVarOld'])
